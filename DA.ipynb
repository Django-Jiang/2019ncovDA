# %% [markdown]
# # 2019ncov
# ## The project 2019ncov, is a data analysis project.
#
# ## Any analysis result/conclusion just for code practice.
#
# ## DO NOT take it as series result according to the data

# %% [markdown]
# ## 1. Read Data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.io as sio
import seaborn as sns

# %%
filename = "2019ncov.csv"
data = pd.read_csv(filename)

# %%
data
# Out:
#     Date  DomesticInfected  Suspected  Dead  Cured
# 0   1/19               198        NaN     3     25
# 1   1/20               291       54.0     6     25
# 2   1/21               440        NaN     9     28
# 3   1/22               571      393.0    17     28
# 4   1/23               830     1072.0    25     34
# 5   1/24              1287     1965.0    41     38
# 6   1/25              1975     2684.0    56     49
# 7   1/26              2744     5794.0    80     51
# 8   1/27              4515     6973.0   106     60
# 9   1/28              5974     9239.0   132    103
# 10  1/29              7711    12167.0   170    124
# 11  1/30              9692    15238.0   213    171
# 12  1/31             11791    17988.0   259    243
# 13   2/1             14830    19544.0   304    328
# 14   2/2             17205    21558.0   361    475
# 15   2/3             20438    23214.0   425    632
# 16   2/4             24324    23260.0   490    892
# ...

# %% [markdown]
# ### Update CSV Data

# %%
def update(data, newval):
    df_new = pd.DataFrame(newval,columns = ['Date','DomesticInfected','Suspected','Dead','Cured'])
    data2 = data.append(df_new, ignore_index=True)
    return data2

data = update(data,[['2/7', 34546, 27657, 722,2050]])
data.to_csv("2019ncov.csv", index = 0)

# %% [markdown]
# ## 2.View data

# %%
data #view raw data
# Out:
#     Date  DomesticInfected  Suspected  Dead  Cured
# 0   1/19               198        NaN     3     25
# 1   1/20               291       54.0     6     25
# 2   1/21               440        NaN     9     28
# 3   1/22               571      393.0    17     28
# 4   1/23               830     1072.0    25     34
# 5   1/24              1287     1965.0    41     38
# 6   1/25              1975     2684.0    56     49
# 7   1/26              2744     5794.0    80     51
# 8   1/27              4515     6973.0   106     60
# 9   1/28              5974     9239.0   132    103
# 10  1/29              7711    12167.0   170    124
# 11  1/30              9692    15238.0   213    171
# 12  1/31             11791    17988.0   259    243
# 13   2/1             14830    19544.0   304    328
# 14   2/2             17205    21558.0   361    475
# 15   2/3             20438    23214.0   425    632
# 16   2/4             24324    23260.0   490    892
# ...

# %%
#plot the data
data2 = data[['Date','Dead','Cured']]

data2.plot()
plt.show()


data.plot(kind= 'bar')
plt.show()

data.plot(kind = 'bar', stacked = 1)
plt.show()

data.plot(kind = 'area')
plt.show()

# %%
data.to_excel("2019ncov2.xlsx", index = 0)

# %%
! git add .
! git commit -m "2.8update_1"
! git push
# Out:
# [master 0c63e33] 2.8update_1
#  8 files changed, 9014 insertions(+), 245 deletions(-)
#  create mode 100644 1.png
#  create mode 100644 Crawler-DailyData/Crawler_DailyData.ipynb
#  create mode 100644 Crawler-DailyData/get.json
#  create mode 100644 Crawler-DailyData/timeline.json
#  rewrite DA.ipynb (89%)
# Enumerating objects: 16, done.
# Counting objects: 100% (16/16), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (11/11), done.
# Writing objects: 100% (11/11), 80.57 KiB | 7.32 MiB/s, done.
# Total 11 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/Django-Jiang/2019ncovDA.git
#    4b15164..0c63e33  master -> master
